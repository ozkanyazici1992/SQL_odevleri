# %% [markdown]
# ÖZKAN YAZICI SQL KÜMELEME VE GRUPLAMA ÖDEVİ

# %% [markdown]
# 1. Maximum kredi limiti nedir? Hangi müşteriye ait?

# %%
import pandas as pd

# %%
cevap1= pd.read_csv("sql21.csv")
cevap1
# Out:
#         customerName  customerNumber  kredi_limiti
# 0  Atelier graphique             103      227600.0

# %% [markdown]
# 2) Her ülkeden kaç müşteri var?

# %%
cevap1= pd.read_csv("sql22.csv")
cevap1
# Out:
#          country  Müşteri_Sayısı
# 0         France              12
# 1            USA              36
# 2      Australia               5
# 3         Norway               3
# 4         Poland               1
# 5        Germany              13
# 6          Spain               7
# 7         Sweden               2
# 8        Denmark               2
# 9      Singapore               3
# 10      Portugal               2
# 11         Japan               2
# 12       Finland               3
# 13            UK               5
# 14       Ireland               2
# 15        Canada               3
# 16     Hong Kong               1
# 17         Italy               4
# 18   Switzerland               3
# 19   Netherlands               1
# 20       Belgium               2
# 21   New Zealand               4
# 22  South Africa               1
# 23       Austria               2
# 24   Philippines               1
# 25        Russia               1
# 26        Israel               1

# %% [markdown]
# 3) En az sipariş veren müşteri numarası ve sipariş sayısı nedir (orders tablosundan)?

# %%
cevap1= pd.read_csv("sql23.csv")
cevap1
# Out:
#    customerNumber  min(siparis_sayisi)
# 0             415                    1
